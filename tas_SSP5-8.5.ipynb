# %%
import xarray as xr
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
import netCDF4
from matplotlib.pyplot import cycler
import matplotlib.colors as mcolors
# %matplotlib inline

# %%
area1 = xr.open_dataset('areacella_fx_CanESM5_historical_r10i1p1f1_gn.nc').areacella
area2 = xr.open_dataset('areacella_fx_CanESM5-CanOE_historical_r1i1p2f1_gn.nc').areacella
area3 = xr.open_dataset('areacella_fx_HadGEM3-GC31-LL_piControl_r1i1p1f1_native.nc').areacella
area4 = xr.open_dataset('areacella_fx_UKESM1-0-LL_piControl_r1i1p1f2_native.nc').areacella
area5 = xr.open_dataset('areacella_fx_E3SM-1-1_historical_r1i1p1f1_gr.nc').areacella
area6 = xr.open_dataset('areacella_fx_CESM2_historical_r1i1p1f1_gn.nc').areacella
area7 = xr.open_dataset('areacella_fx_CNRM-CM6-1_historical_r1i1p1f2_gr.nc').areacella
area8 = xr.open_dataset('areacella_fx_CNRM-ESM2-1_historical_r10i1p1f2_gr.nc').areacella
area9 = xr.open_dataset('areacella_fx_IPSL-CM6A-LR_historical_r1i1p1f1_gr.nc').areacella
area10 = xr.open_dataset('areacella_fx_CESM2-WACCM_historical_r1i1p1f1_gn.nc').areacella
area11 = xr.open_dataset('areacella_fx_ACCESS-CM2_historical_r1i1p1f1_gn.nc').areacella
area12 = xr.open_dataset('areacella_fx_TaiESM1_historical_r1i1p1f1_gn.nc').areacella
# Out:
# /usr/local/Miniconda3-envs/envs/2021/envs/iacpy3_2021/lib/python3.9/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'areacella' has multiple fill values {1e+20, 1e+20}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(

# %%
area13 = xr.open_dataset('areacella_fx_CNRM-CM6-1-HR_historical_r1i1p1f2_gr.nc').areacella
area14 = xr.open_dataset('areacella_fx_EC-Earth3-Veg_historical_r12i1p1f1_gr.nc').areacella
area15 = xr.open_dataset('areacella_fx_EC-Earth3_historical_r1i1p1f1_gr.nc').areacella
area16 = xr.open_dataset('areacella_fx_EC-Earth3-CC_historical_r1i1p1f1_gr.nc').areacella
area17 = xr.open_dataset('areacella_fx_GFDL-CM4_historical_r1i1p1f1_gr1.nc').areacella
area18 = xr.open_dataset('areacella_fx_ACCESS-ESM1-5_historical_r1i1p1f1_gn.nc').areacella
area19 = xr.open_dataset('areacella_fx_CMCC-ESM2_historical_r1i1p1f1_gn.nc').areacella
area20 = xr.open_dataset('areacella_fx_CMCC-CM2-SR5_historical_r1i1p1f1_gn.nc').areacella
area21 = xr.open_dataset('areacella_fx_AWI-CM-1-1-MR_historical_r1i1p1f1_gn.nc').areacella
area22 = xr.open_dataset('areacella_fx_MRI-ESM2-0_historical_r1i1p1f1_gn.nc').areacella
area23 = xr.open_dataset('areacella_fx_MPI-ESM1-2-LR_historical_r1i1p1f1_gn.nc').areacella

# %%
area24 = xr.open_dataset('areacella_fx_MPI-ESM1-2-HR_historical_r1i1p1f1_gn.nc').areacella
area25 = xr.open_dataset('areacella_fx_FGOALS-g3_historical_r1i1p1f1_gn.nc').areacella
area26 = xr.open_dataset('areacella_fx_GISS-E2-1-G_piControl_r1i1p1f1_native.nc').areacella
area27 = xr.open_dataset('areacella_fx_MIROC-ES2L_historical_r10i1p1f2_gn.nc').areacella
area28 = xr.open_dataset('areacella_fx_GFDL-ESM4_historical_r1i1p1f1_gr1.nc').areacella
area29 = xr.open_dataset('areacella_fx_MIROC6_historical_r1i1p1f1_gn.nc').areacella
area30 = xr.open_dataset('areacella_fx_NorESM2-LM_historical_r1i1p1f1_gn.nc').areacella
area31 =xr.open_dataset('areacella_fx_INM-CM5-0_historical_r1i1p1f1_gr1.nc').areacella
area32 = xr.open_dataset('areacella_fx_INM-CM4-8_historical_r1i1p1f1_gr1.nc').areacella

# %%
ds1 = xr.open_dataset('tas_Amon_CanESM5_hist_ssp585_r10i1p1f1_gn_185001-210012.nc')
ds2 = xr.open_dataset('tas_Amon_CanESM5-CanOE_hist_ssp585_r1i1p2f1_gn_185001-210012.nc')
ds3 = xr.open_dataset('tas_Amon_HadGEM3-GC31-LL_hist_ssp585_r1i1p1f3_gn_185001-210012.nc')
ds4 = xr.open_dataset('tas_Amon_UKESM1-0-LL_hist_ssp585_r1i1p1f2_gn_185001-210012.nc')
ds5 = xr.open_dataset('tas_Amon_E3SM-1-1_hist_ssp585_r1i1p1f1_gr_185001-210012.nc')
ds6 = xr.open_dataset('tas_Amon_CESM2_hist_ssp585_r1i1p1f1_gn_185001-210012.nc')
ds7 = xr.open_dataset('tas_Amon_CNRM-CM6-1_hist_ssp585_r1i1p1f2_gr_185001-210012.nc')
ds8 = xr.open_dataset('tas_Amon_CNRM-ESM2-1_hist_ssp585_r1i1p1f2_gr_185001-210012.nc')
ds9 = xr.open_dataset('tas_Amon_IPSL-CM6A-LR_hist_ssp585_r1i1p1f1_gr_185001-210012.nc')
ds10 = xr.open_dataset('tas_Amon_CESM2-WACCM_hist_ssp585_r1i1p1f1_gn_185001-210012.nc')
ds11 = xr.open_dataset('tas_Amon_ACCESS-CM2_hist_ssp585_r1i1p1f1_gn_185001-210012.nc')
ds12 = xr.open_dataset('tas_Amon_TaiESM1_hist_ssp585_r1i1p1f1_gn_185001-210012.nc')
# Out:
# /usr/local/Miniconda3-envs/envs/2021/envs/iacpy3_2021/lib/python3.9/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'tas' has multiple fill values {1e+20, 1e+20}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(

# %%
ds13 = xr.open_dataset('tas_Amon_CNRM-CM6-1-HR_hist_ssp585_r1i1p1f2_gr_185001-210012.nc')
ds14 = xr.open_dataset('tas_Amon_EC-Earth3-Veg_hist_ssp585_r1i1p1f1_gr_185001-210012.nc')
ds15 = xr.open_dataset('tas_Amon_EC-Earth3_hist_ssp585_r4i1p1f1_gr_185001-210012.nc')
ds16 = xr.open_dataset('tas_Amon_EC-Earth3-CC_hist_ssp585_r1i1p1f1_gr_185001-210012.nc')
ds17 = xr.open_dataset('tas_Amon_GFDL-CM4_hist_ssp585_r1i1p1f1_gr1_185001-210012.nc')
ds18 = xr.open_dataset('tas_Amon_ACCESS-ESM1-5_hist_ssp585_r1i1p1f1_gn_185001-210012.nc')
ds19 = xr.open_dataset('tas_Amon_CMCC-ESM2_hist_ssp585_r1i1p1f1_gn_185001-210012.nc')
ds20 = xr.open_dataset('tas_Amon_CMCC-CM2-SR5_hist_ssp585_r1i1p1f1_gn_185001-210012.nc')
ds21 = xr.open_dataset('tas_Amon_AWI-CM-1-1-MR_hist_ssp585_r1i1p1f1_gn_185001-210012.nc')
ds22 = xr.open_dataset('tas_Amon_MRI-ESM2-0_hist_ssp585_r1i1p1f1_gn_185001-210012.nc')
ds23 = xr.open_dataset('tas_Amon_MPI-ESM1-2-LR_hist_ssp585_r1i1p1f1_gn_185001-210012.nc')

# %%
ds24 = xr.open_dataset('tas_Amon_MPI-ESM1-2-HR_hist_ssp585_r1i1p1f1_gn_185001-210012.nc')
ds25 = xr.open_dataset('tas_Amon_FGOALS-g3_hist_ssp585_r1i1p1f1_gn_185001-210012.nc')
ds26 = xr.open_dataset('tas_Amon_GISS-E2-1-G_hist_ssp585_r1i1p1f2_gn_185001-210012.nc')
ds27 = xr.open_dataset('tas_Amon_MIROC-ES2L_hist_ssp585_r10i1p1f2_gn_185001-210012.nc')
ds28 = xr.open_dataset('tas_Amon_GFDL-ESM4_hist_ssp585_r1i1p1f1_gr1_185001-210012.nc')
ds29 = xr.open_dataset('tas_Amon_MIROC6_hist_ssp585_r1i1p1f1_gn_185001-210012.nc')
ds30 = xr.open_dataset('tas_Amon_NorESM2-LM_hist_ssp585_r1i1p1f1_gn_185001-210012.nc')
ds31 = xr.open_dataset('tas_Amon_INM-CM5-0_hist_ssp585_r1i1p1f1_gr1_185001-210012.nc')
ds32 = xr.open_dataset('tas_Amon_INM-CM4-8_hist_ssp585_r1i1p1f1_gr1_185001-210012.nc')

# %%
dset_dict = {'CanESM5':ds1, 'CanESM5-CanOE':ds2, 'HadGEM3-GC31-LL':ds3, 'UKESM1-0-LL':ds4, 'E3SM-1-1':ds5, 'CESM2':ds6, 'CNRM-CM6-1':ds7, 'CNRM-ESM2-1':ds8, 'IPSL-CM6A-LR':ds9,
            'CESM2-WACCM':ds10, 'ACCESS-CM2':ds11, 'TaiESM1':ds12, 'CNRM-CM6-1-HR':ds13, 'EC-Earth3-Veg':ds14, 'EC-Earth3':ds15, 'EC-Earth3-CC':ds16, 
            'GFDL-CM4':ds17, 'ACCESS-ESM1-5':ds18, 'CMCC-ESM2':ds19, 'CMCC-CM2-SR5':ds20, 'AWI-CM-1-1-MR':ds21, 'MRI-ESM2-0':ds22, 'MPI-ESM1-2-LR':ds23,
            'MPI-ESM1-2-HR':ds24, 'FGOALS-g3':ds25, 'GISS-E2-1-G':ds26, 'MIROC-ES2L':ds27, 'GFDL-ESM4':ds28, 'MIROC6':ds29,
            'NorESM2-LM':ds30, 'INM-CM5-0':ds31, 'INM-CM4-8':ds32}

# %%
time_slice=slice('1850', '2100')

# %%
#initialize dictionary of xarray datasets
tas_dict = {}

for name, ds in dset_dict.items():
    # rename spatial dimension if necessary
    if ('longitude' in ds.dims) and ('latitude' in ds.dims): 
        ds = ds.rename({'longitude':'lon', 'latitude': 'lat'})
    
    ds = xr.decode_cf(ds) # needed to keep the time dimensions consistent
    ds = ds.sel(time=time_slice) # subset the data for the time period of interest
    
    # select input variable
    tas = ds['tas'] #input variable
    # select the region of interest
    # tas_mon=tas_mon.sel(lon=slice(lon1,lon2), lat=slice(lat1,lat2))
    
    # drop redundant variables (like "height: 2m")
    for coord in ds.coords:
        if coord not in ['lat', 'lon', 'time']:
            ds = ds.drop(coord)

    tas_dict[name] = ds

# %%
#effective area weights and calculating global-mean surface temperature
gsat1 = tas_dict['CanESM5'].tas.weighted(area1).mean(('lon','lat'))
gsat2 = tas_dict['CanESM5-CanOE'].tas.weighted(area2).mean(('lon','lat'))
gsat3 = tas_dict['HadGEM3-GC31-LL'].tas.weighted(area3).mean(('lon','lat'))
gsat4 = tas_dict['UKESM1-0-LL'].tas.weighted(area4).mean(('lon','lat'))
gsat5 = tas_dict['E3SM-1-1'].tas.weighted(area5).mean(('lon','lat'))
gsat6 = tas_dict['CESM2'].tas.weighted(area6).mean(('lon','lat'))
gsat7 = tas_dict['CNRM-CM6-1'].tas.weighted(area7).mean(('lon','lat'))
gsat8 = tas_dict['CNRM-ESM2-1'].tas.weighted(area8).mean(('lon','lat'))
gsat9 = tas_dict['IPSL-CM6A-LR'].tas.weighted(area9).mean(('lon','lat'))
gsat10 = tas_dict['CESM2-WACCM'].tas.weighted(area10).mean(('lon','lat'))
gsat11 = tas_dict['ACCESS-CM2'].tas.weighted(area11).mean(('lon','lat'))
gsat12 = tas_dict['TaiESM1'].tas.weighted(area12).mean(('lon','lat'))
gsat13 = tas_dict['CNRM-CM6-1-HR'].tas.weighted(area13).mean(('lon','lat'))
gsat14 = tas_dict['EC-Earth3-Veg'].tas.weighted(area14).mean(('lon','lat'))
gsat15 = tas_dict['EC-Earth3'].tas.weighted(area15).mean(('lon','lat'))
gsat16 = tas_dict['EC-Earth3-CC'].tas.weighted(area16).mean(('lon','lat'))
gsat17 = tas_dict['GFDL-CM4'].tas.weighted(area17).mean(('lon','lat'))
gsat18 = tas_dict['ACCESS-ESM1-5'].tas.weighted(area18).mean(('lon','lat'))
gsat19 = tas_dict['CMCC-ESM2'].tas.weighted(area19).mean(('lon','lat'))
gsat20 = tas_dict['CMCC-CM2-SR5'].tas.weighted(area20).mean(('lon','lat'))
gsat21 = tas_dict['AWI-CM-1-1-MR'].tas.weighted(area21).mean(('lon','lat'))
gsat22 = tas_dict['MRI-ESM2-0'].tas.weighted(area22).mean(('lon','lat'))
gsat23 = tas_dict['MPI-ESM1-2-LR'].tas.weighted(area23).mean(('lon','lat'))
gsat24 = tas_dict['MPI-ESM1-2-HR'].tas.weighted(area24).mean(('lon','lat'))
gsat25 = tas_dict['FGOALS-g3'].tas.weighted(area25).mean(('lon','lat'))
gsat26 = tas_dict['GISS-E2-1-G'].tas.weighted(area26).mean(('lon','lat'))
gsat27 = tas_dict['MIROC-ES2L'].tas.weighted(area27).mean(('lon','lat'))
gsat28 = tas_dict['GFDL-ESM4'].tas.weighted(area28).mean(('lon','lat'))
gsat29 = tas_dict['MIROC6'].tas.weighted(area29).mean(('lon','lat'))
gsat30 = tas_dict['NorESM2-LM'].tas.weighted(area30).mean(('lon','lat'))
gsat31 = tas_dict['INM-CM5-0'].tas.weighted(area31).mean(('lon','lat'))
gsat32 = tas_dict['INM-CM4-8'].tas.weighted(area32).mean(('lon','lat'))

# %%
gsat_dict = {'CanESM5':gsat1, 'CanESM5-CanOE':gsat2, 'HadGEM3-GC31-LL':gsat3, 'UKESM1-0-LL':gsat4, 'E3SM-1-1':gsat5, 'CESM2':gsat6, 'CNRM-CM6-1':gsat7, 'CNRM-ESM2-1':gsat8, 'IPSL-CM6A-LR':gsat9,
            'CESM2-WACCM':gsat10, 'ACCESS-CM2':gsat11, 'TaiESM1':gsat12, 'CNRM-CM6-1-HR':gsat13, 'EC-Earth3-Veg':gsat14, 'EC-Earth3':gsat15, 'EC-Earth3-CC':gsat16, 
            'GFDL-CM4':gsat17, 'ACCESS-ESM1-5':gsat18, 'CMCC-ESM2':gsat19, 'CMCC-CM2-SR5':gsat20, 'AWI-CM-1-1-MR':gsat21, 'MRI-ESM2-0':gsat22, 'MPI-ESM1-2-LR':gsat23,
            'MPI-ESM1-2-HR':gsat24, 'FGOALS-g3':gsat25, 'GISS-E2-1-G':gsat26, 'MIROC-ES2L':gsat27, 'GFDL-ESM4':gsat28, 'MIROC6':gsat29,
            'NorESM2-LM':gsat30, 'INM-CM5-0':gsat31, 'INM-CM4-8':gsat32}

# %% [markdown]
# ## Plotting Time Series: Changes in global mean surface temperature (1850-2100 wrt 1850-1900)

# %%
for name, gsat in gsat_dict.items():
    
    # reference the GSAT relative to the 1850 to 1900 pre-industrial period
    gsat_anomalies = gsat - gsat.sel(time=slice('1850','1900')).mean(dim='time')
    
    gsat_ann_anomalies = gsat_anomalies.groupby('time.year').mean('time')
        
    # renaming labels
    gsat_ann_anomalies = gsat_ann_anomalies.rename(
        r'tas anomaly (relative to 1850-1900)'
    )
    
    gsat_dict[name] = gsat_ann_anomalies.compute()

# %%
gsat_ann_anomalies.dims, gsat_ann_anomalies.shape, gsat_ann_anomalies.coords
# Out:
# (('year',),
#  (251,),
#  Coordinates:
#    * year     (year) int64 1850 1851 1852 1853 1854 ... 2096 2097 2098 2099 2100)

# %%
gsat32_roll = gsat_dict['INM-CM4-8'].rolling(year=10).mean()
gsat31_roll = gsat_dict['INM-CM5-0'].rolling(year=10).mean()
gsat30_roll = gsat_dict['NorESM2-LM'].rolling(year=10).mean()
gsat29_roll = gsat_dict['MIROC6'].rolling(year=10).mean()
gsat28_roll = gsat_dict['GFDL-ESM4'].rolling(year=10).mean()
gsat27_roll = gsat_dict['MIROC-ES2L'].rolling(year=10).mean()
gsat26_roll = gsat_dict['GISS-E2-1-G'].rolling(year=10).mean() 
gsat25_roll = gsat_dict['FGOALS-g3'].rolling(year=10).mean()
gsat24_roll = gsat_dict['MPI-ESM1-2-HR'].rolling(year=10).mean()
gsat23_roll = gsat_dict['MPI-ESM1-2-LR'].rolling(year=10).mean()
gsat22_roll = gsat_dict['MRI-ESM2-0'].rolling(year=10).mean()
gsat21_roll = gsat_dict['AWI-CM-1-1-MR'].rolling(year=10).mean()
gsat20_roll = gsat_dict['CMCC-CM2-SR5'].rolling(year=10).mean()
gsat19_roll = gsat_dict['CMCC-ESM2'].rolling(year=10).mean()
gsat18_roll = gsat_dict['ACCESS-ESM1-5'].rolling(year=10).mean()
gsat17_roll = gsat_dict['GFDL-CM4'].rolling(year=10).mean()
gsat16_roll = gsat_dict['EC-Earth3-CC'].rolling(year=10).mean()
gsat15_roll = gsat_dict['EC-Earth3'].rolling(year=10).mean()
gsat14_roll = gsat_dict['EC-Earth3-Veg'].rolling(year=10).mean()
gsat13_roll = gsat_dict['CNRM-CM6-1-HR'].rolling(year=10).mean()
gsat12_roll = gsat_dict['TaiESM1'].rolling(year=10).mean()
gsat11_roll = gsat_dict['ACCESS-CM2'].rolling(year=10).mean()
gsat10_roll = gsat_dict['CESM2-WACCM'].rolling(year=10).mean()
gsat9_roll = gsat_dict['IPSL-CM6A-LR'].rolling(year=10).mean()
gsat8_roll = gsat_dict['CNRM-ESM2-1'].rolling(year=10).mean()
gsat7_roll = gsat_dict['CNRM-CM6-1'].rolling(year=10).mean()
gsat6_roll = gsat_dict['CESM2'].rolling(year=10).mean()
gsat5_roll = gsat_dict['E3SM-1-1'].rolling(year=10).mean()
gsat4_roll = gsat_dict['UKESM1-0-LL'].rolling(year=10).mean()
gsat3_roll = gsat_dict['HadGEM3-GC31-LL'].rolling(year=10).mean()
gsat2_roll = gsat_dict['CanESM5-CanOE'].rolling(year=10).mean()
gsat1_roll = gsat_dict['CanESM5'].rolling(year=10).mean()

#calculate modelmean
modelmean = (gsat1_roll + gsat2_roll + gsat3_roll + gsat4_roll +gsat5_roll+gsat6_roll+gsat7_roll+gsat8_roll+gsat9_roll
             +gsat10_roll+gsat11_roll+gsat12_roll+gsat13_roll+ gsat14_roll + gsat15_roll + gsat16_roll + gsat17_roll +gsat18_roll
             +gsat19_roll+gsat20_roll+gsat21_roll+gsat22_roll+gsat23_roll+gsat24_roll+gsat25_roll+gsat26_roll+gsat27_roll
             +gsat28_roll+gsat29_roll+gsat30_roll+gsat31_roll+gsat32_roll)/32

# %%
fig,ax = plt.subplots(figsize=(10,5))

gsat32_roll.plot(linewidth=1, label='INM-CM4-8')
gsat31_roll.plot(linewidth=1, label='INM-CM5-0')
gsat30_roll.plot(linewidth=1, label='NorESM2-LM')
gsat29_roll.plot(linewidth=1, label='MIROC6')
gsat28_roll.plot(linewidth=1, label='GFDL-ESM4')
gsat27_roll.plot(linewidth=1, label='MIROC-ES2L')
gsat26_roll.plot(linewidth=1, label='GISS-E2-1-G') 
gsat25_roll.plot(linewidth=1, label='FGOALS-g3')
gsat24_roll.plot(linewidth=1, label='MPI-ESM1-2-HR')
gsat23_roll.plot(linewidth=1, label='MPI-ESM1-2-LR')
gsat22_roll.plot(linewidth=1, label='MRI-ESM2-0')
gsat21_roll.plot(linewidth=1, label='AWI-CM-1-1-MR')
gsat20_roll.plot(linewidth=1, label='CMCC-CM2-SR5')
gsat19_roll.plot(linewidth=1, label='CMCC-ESM2')
gsat18_roll.plot(linewidth=1, label='ACCESS-ESM1-5')
gsat17_roll.plot(linewidth=1, label='GFDL-CM4')
gsat16_roll.plot(linewidth=1, label='EC-Earth3-CC')
gsat15_roll.plot(linewidth=1, label='EC-Earth3')
gsat14_roll.plot(linewidth=1, label='EC-Earth3-Veg')
gsat13_roll.plot(linewidth=1, label='CNRM-CM6-1-HR')
gsat12_roll.plot(linewidth=1, label='TaiESM1')
gsat11_roll.plot(linewidth=1, label='ACCESS-CM2')
gsat10_roll.plot(linewidth=1, label='CESM2-WACCM')
gsat9_roll.plot(linewidth=1, label='IPSL-CM6A-LR')
gsat8_roll.plot(linewidth=1, label='CNRM-ESM2-1')
gsat7_roll.plot(linewidth=1, label='CNRM-CM6-1')
gsat6_roll.plot(linewidth=1, label='CESM2')
gsat5_roll.plot(linewidth=1, label='E3SM-1-1')
gsat4_roll.plot(linewidth=1, label='UKESM1-0-LL')
gsat3_roll.plot(linewidth=1, label='HadGEM3-GC31-LL')
gsat2_roll.plot(linewidth=1, label='CanESM5-CanOE')
gsat1_roll.plot(linewidth=1, label='CanESM5')

#add modelmean
modelmean.plot(linewidth=4, color= 'black', label= 'Model Mean')

#add right colors
N=32
plt.rcParams["axes.prop_cycle"] = plt.cycler("color", plt.cm.Reds(np.linspace(0,1,N)))

# set titel and name for axes
#plt.title('Changes in the global mean surface air temperature', fontsize = 14, fontweight = 'bold')
ax.text(0.01, 0.95, 'tas', 
        transform=ax.transAxes, ha="left", fontsize= 14, fontweight = 'bold')
ax.text(0.009, 0.01, 'n=32', 
        transform=ax.transAxes, ha="left", fontsize= 14)
plt.xlabel('Time (years)', fontsize = 12)
plt.ylabel(r'Global-mean surface temperature anomaly ($^{\circ}$C)', fontsize = 12)
plt.xlim([1850,2100])
plt.ylim([-0.5,8])

# plotting legend
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[::-1], labels[::-1],bbox_to_anchor=(0, -0.12, 1, 0), loc="upper left", mode="expand", ncol=4)
    
# adding horizontal lines 1.5°C and 2°C
plt.axhline(1.5, color='tab:red', linestyle='--', linewidth=1.5)
plt.axhline(2.0, color='tab:red', linestyle='--', linewidth=1.5)

plt.savefig('TimeSeriesMultiModelTempChanges.png', bbox_inches="tight")
plt.show();

# %%
max_tas = max(modelmean)  # Find the maximum y value
max_year = modelmean[modelmean.argmax()]  # Find the x value corresponding to the maximum y value
print (max_year, max_tas)
# Out:
# <xarray.DataArray 'tas anomaly (relative to 1850-1900)' ()>
# array(5.475404, dtype=float32)
# Coordinates:
#     year     int64 2100 <xarray.DataArray 'tas anomaly (relative to 1850-1900)' ()>
# array(nan, dtype=float32)
# Coordinates:
#     year     int64 1850

# %%
modelmean.sel(year=slice('2077','2087'))
# Out:
# <xarray.DataArray 'tas anomaly (relative to 1850-1900)' (year: 11)>
# array([3.9545429, 4.0134163, 4.0743084, 4.136982 , 4.203613 , 4.2693605,
#        4.327228 , 4.3926935, 4.467047 , 4.537908 , 4.605254 ],
#       dtype=float32)
# Coordinates:
#   * year     (year) int64 2077 2078 2079 2080 2081 2082 2083 2084 2085 2086 2087

# %%
modelmean.sel(year=slice('2077','2087')).mean()
# Out:
# <xarray.DataArray 'tas anomaly (relative to 1850-1900)' ()>
# array(4.271123, dtype=float32)

# %%
modelmean.sel(year=slice('2090','2100'))
# Out:
# <xarray.DataArray 'tas anomaly (relative to 1850-1900)' (year: 11)>
# array([4.809212 , 4.8741207, 4.9407954, 5.012787 , 5.0780864, 5.141819 ,
#        5.2091217, 5.277467 , 5.346009 , 5.4126086, 5.475404 ],
#       dtype=float32)
# Coordinates:
#   * year     (year) int64 2090 2091 2092 2093 2094 2095 2096 2097 2098 2099 2100

# %%
modelmean.sel(year=slice('2090','2100')).mean()
# Out:
# <xarray.DataArray 'tas anomaly (relative to 1850-1900)' ()>
# array(5.1434026, dtype=float32)

# %%
modelmean.sel(year=slice('2010','2020')).mean()
# Out:
# <xarray.DataArray 'tas anomaly (relative to 1850-1900)' ()>
# array(1.0543617, dtype=float32)

# %%
def minpass(mymarks, mypass):
    passed= [x for x in mymarks if x >= mypass]
    min_value = passed[0]
    for x in passed: 
        if x < min_value:
            min_value = x
    return min_value

x = modelmean 
y = 1.5

minpass(x, y)
# Out:
# <xarray.DataArray 'tas anomaly (relative to 1850-1900)' ()>
# array(1.5121588, dtype=float32)
# Coordinates:
#     year     int64 2029

# %%
def minpass(mymarks, mypass):
    passed= [x for x in mymarks if x >= mypass]
    min_value = passed[0]
    for x in passed: 
        if x < min_value:
            min_value = x
    return min_value

x = modelmean 
y = 2.0

minpass(x, y)
# Out:
# <xarray.DataArray 'tas anomaly (relative to 1850-1900)' ()>
# array(2.0209696, dtype=float32)
# Coordinates:
#     year     int64 2042

# %% [markdown]
# # Plotting Maps of hot model: CanESM5 (ECS 5.64)

# %%
# Selecting model out of dictionary
ssp_hot1 = tas_dict[list(tas_dict.keys())[0]]
ssp_hot1.attrs['parent_source_id']
# Out:
# 'CanESM5'

# %%
# check units
ssp_hot1.tas.attrs['units']
# Out:
# 'K'

# %%
# convert units to Celcius
ssp_hot1.tas.data = ssp_hot1.tas.data - 273.15
ssp_hot1.tas.attrs['units'] = 'Celcius'
ssp_hot1.tas.attrs['units']
# Out:
# 'Celcius'

# %%
# display years in this dataset
print(ssp_hot1.tas.time)
# Out:
# <xarray.DataArray 'time' (time: 3012)>
# array([cftime.DatetimeNoLeap(1850, 1, 16, 12, 0, 0, 0),
#        cftime.DatetimeNoLeap(1850, 2, 15, 0, 0, 0, 0),
#        cftime.DatetimeNoLeap(1850, 3, 16, 12, 0, 0, 0), ...,
#        cftime.DatetimeNoLeap(2100, 10, 16, 12, 0, 0, 0),
#        cftime.DatetimeNoLeap(2100, 11, 16, 0, 0, 0, 0),
#        cftime.DatetimeNoLeap(2100, 12, 16, 12, 0, 0, 0)], dtype=object)
# Coordinates:
#   * time     (time) object 1850-01-16 12:00:00 ... 2100-12-16 12:00:00
# Attributes:
#     bounds:         time_bnds
#     axis:           T
#     long_name:      time
#     standard_name:  time

# %%
plt.figure(figsize=(10,5))

gsat1_roll = gsat_dict['CanEsm5'].rolling(year=10).mean()
gsat1_roll.plot(linewidth=1, color='black', label='CanEsm5')

# set titel and name for axes
plt.title('Model %s (baseline 1850–1900)' %(ssp_hot1.attrs['parent_source_id']), 
         fontsize = 14, fontweight = 'bold')
plt.xlabel('Time (years)')
plt.ylabel(r'Global-mean surface air temperature anomaly ($^{\circ}$C)')
plt.xlim([1850,2100])

# plotting legend
plt.legend()
    
# adding horizontal lines 1.5°C and 2°C
plt.axhline(1.5, color='dimgrey', linestyle='--', linewidth=0.5)
plt.axhline(2.0, color='dimgrey', linestyle='--', linewidth=0.5)

plt.savefig("CanESM5 Time Series Temperature.png")
plt.show();

# %% [markdown]
# ## Plotting CanESM5 at time of temperature 1.5°C

# %%
def minpass(mymarks, mypass):
    passed= [x for x in mymarks if x >= mypass]
    min_value = passed[0]
    for x in passed: 
        if x < min_value:
            min_value = x
    return min_value

x = gsat1_roll 
y = 1.5

pass_min = minpass(x, y)
print(pass_min)
# Out:
# <xarray.DataArray 'tas anomaly (relative to 1850-1900)' ()>
# array(1.5162565, dtype=float32)
# Coordinates:
#     year     int64 2014

# %%
minyear=pass_min.year.values - 5
maxyear=pass_min.year.values + 5
min_max = '%s - %s' %(minyear, maxyear)
min_max
# Out:
# '2009 - 2019'

# %%
temperature_change = (
    ssp_hot1['tas'].sel(time=slice('2009','2019')).mean(dim='time') -
    ssp_hot1['tas'].sel(time=slice('1850','1900')).mean(dim='time')
).compute()
temperature_change.attrs.update(ssp_hot1.attrs)
temperature_change = temperature_change.rename(
    r'Temperature anomaly ($^{\circ}$C) from 1850-1900'
)

# %%
#choose projection: robinson projection
robin = ccrs.Robinson(central_longitude=0) # define target coordinate frame
geo = ccrs.PlateCarree() # define origin coordinate frame

plt.figure(figsize=(12,5))
ax = plt.subplot(1, 1, 1, projection=robin)

#set min/max values for the colorbar
norm = mpl.colors.Normalize(vmin=0, vmax=10)

q = temperature_change.plot(ax=ax, cmap='YlOrRd',norm=norm, transform = geo) # plot a colormap in transformed coordinates

#add coastlines
ax.coastlines
#Add title with the model name
title = '%s surface air temperature anomaly at global mean 1.5$^{\circ}$C (%s)' %(ssp_hot1.attrs['parent_source_id'], min_max)
plt.title(title);
#save figure
plt.savefig("CanESM5 Anomaly 1.5C Global Map.png")

# %% [markdown]
# ## Plotting CanESM5 at time of temperature 2.0°C

# %%
def minpass(mymarks, mypass):
    passed= [x for x in mymarks if x >= mypass]
    min_value = passed[0]
    for x in passed: 
        if x < min_value:
            min_value = x
    return min_value

x = gsat1_roll 
y = 2.0

pass_min = minpass(x, y)
print(pass_min)
# Out:
# <xarray.DataArray 'tas anomaly (relative to 1850-1900)' ()>
# array(2.0070436, dtype=float32)
# Coordinates:
#     year     int64 2026

# %%
minyear=pass_min.year.values - 5
maxyear=pass_min.year.values + 5
min_max = '%s - %s' %(minyear, maxyear)
min_max
# Out:
# '2021 - 2031'

# %%
temperature_change = (
    ssp_hot1['tas'].sel(time=slice('2021','2031')).mean(dim='time') -
    ssp_hot1['tas'].sel(time=slice('1850','1900')).mean(dim='time')
).compute()
temperature_change.attrs.update(ssp_hot1.attrs)
temperature_change = temperature_change.rename(
    r'Temperature anomaly ($^{\circ}$C) from 1850-1900'
)

# %%
#choose projection: robinson projection
robin = ccrs.Robinson(central_longitude=0) # define target coordinate frame
geo = ccrs.PlateCarree() # define origin coordinate frame

plt.figure(figsize=(12,5))
ax = plt.subplot(1, 1, 1, projection=robin)

#set min/max values for the colorbar
norm = mpl.colors.Normalize(vmin=0, vmax=10)

q = temperature_change.plot(ax=ax, cmap='YlOrRd',norm=norm, transform = geo) # plot a colormap in transformed coordinates

#add coastlines
ax.coastlines()
#Add title with the model name
title = '%s surface air temperature anomaly at global mean 2.0$^{\circ}$C (%s)' %(ssp_hot1.attrs['parent_source_id'], min_max)
plt.title(title);
#save figure
plt.savefig("CanESM5 Temp Anomaly 2.0 Global Map.png")

# %% [markdown]
# ## Plotting CanESM5 at end-of-century wrt to pre-industrial

# %%
temperature_change = (
    ssp_hot1['tas'].sel(time=slice('2080','2100')).mean(dim='time') -
    ssp_hot1['tas'].sel(time=slice('1850','1900')).mean(dim='time')
).compute()
temperature_change.attrs.update(ssp_hot1.attrs)
temperature_change = temperature_change.rename(
    r'Temperature anomaly ($^{\circ}$C) from 1850-1900'
)

# %%
#choose projection: robinson projection
robin = ccrs.Robinson(central_longitude=0) # define target coordinate frame
geo = ccrs.PlateCarree() # define origin coordinate frame

plt.figure(figsize=(12,5))
ax = plt.subplot(1, 1, 1, projection=robin)

#set min/max values for the colorbar
norm = mpl.colors.Normalize(vmin=0, vmax=10)

q = temperature_change.plot(ax=ax, cmap='YlOrRd',norm=norm, transform = geo) # plot a colormap in transformed coordinates

#add coastlines
ax.coastlines()

#Add title with the model name (parent_source_id is the model name, from the dataset attributes)
title = '%s surface air temperature anomaly at end-of-century (2080-2100)' %(ssp_hot1.attrs['parent_source_id'])
plt.title(title);

#save figure
plt.savefig("CanESM5 Temp Anomaly Endofcentury Global Map.jpg")

# %% [markdown]
# # Plotting Maps of hot model: UKESM1-0-LL

# %%
# Selecting model out of dictionary
ssp_hot2 = tas_dict[list(tas_dict.keys())[3]]
ssp_hot2.attrs['parent_source_id']
# Out:
# 'UKESM1-0-LL'

# %%
# check units
ssp_hot2.tas.attrs['units']
# Out:
# 'K'

# %%
# convert units to Celcius
ssp_hot2.tas.data = ssp_hot2.tas.data - 273.15
ssp_hot2.tas.attrs['units'] = 'Celcius'
ssp_hot2.tas.attrs['units']
# Out:
# 'Celcius'

# %%
# display years in this dataset
print(ssp_hot2.tas.time)
# Out:
# <xarray.DataArray 'time' (time: 3012)>
# array([cftime.Datetime360Day(1850, 1, 16, 0, 0, 0, 0),
#        cftime.Datetime360Day(1850, 2, 16, 0, 0, 0, 0),
#        cftime.Datetime360Day(1850, 3, 16, 0, 0, 0, 0), ...,
#        cftime.Datetime360Day(2100, 10, 16, 0, 0, 0, 0),
#        cftime.Datetime360Day(2100, 11, 16, 0, 0, 0, 0),
#        cftime.Datetime360Day(2100, 12, 16, 0, 0, 0, 0)], dtype=object)
# Coordinates:
#   * time     (time) object 1850-01-16 00:00:00 ... 2100-12-16 00:00:00
# Attributes:
#     bounds:         time_bnds
#     axis:           T
#     long_name:      time
#     standard_name:  time

# %%
plt.figure(figsize=(10,5))

gsat4_roll.plot(linewidth=1, color='black', label='UKESM1-0-LL')

# set titel and name for axes
plt.title('Model %s (baseline 1850–1900)' %(ssp_hot2.attrs['parent_source_id']), 
         fontsize = 14, fontweight = 'bold')
plt.xlabel('Time (years)')
plt.ylabel(r'Global-mean surface air temperature anomaly ($^{\circ}$C)')
plt.xlim([1850,2100])

# plotting legend
plt.legend()
    
# adding horizontal lines 1.5°C and 2°C
plt.axhline(1.5, color='dimgrey', linestyle='--', linewidth=0.5)
plt.axhline(2.0, color='dimgrey', linestyle='--', linewidth=0.5)

plt.savefig("UKESM1-0-LL Time Series Temperature.png")
plt.show();

# %% [markdown]
# ## Plotting UKESM1-0-LL at time of temperature 1.5°C

# %%
def minpass(mymarks, mypass):
    passed= [x for x in mymarks if x >= mypass]
    min_value = passed[0]
    for x in passed: 
        if x < min_value:
            min_value = x
    return min_value

x = gsat4_roll 
y = 1.5

pass_min = minpass(x, y)
print(pass_min)
# Out:
# <xarray.DataArray 'tas anomaly (relative to 1850-1900)' ()>
# array(1.501737, dtype=float32)
# Coordinates:
#     year     int64 2028

# %%
minyear=pass_min.year.values - 5
maxyear=pass_min.year.values + 5
min_max = '%s - %s' %(minyear, maxyear)
min_max
# Out:
# '2023 - 2033'

# %%
temperature_change = (
    ssp_hot2['tas'].sel(time=slice('2023','2033')).mean(dim='time') -
    ssp_hot2['tas'].sel(time=slice('1850','1900')).mean(dim='time')
).compute()
temperature_change.attrs.update(ssp_hot2.attrs)
temperature_change = temperature_change.rename(
    r'Δ Temperature ($^{\circ}$C)'
)

# %%
#choose projection: robinson projection
robin = ccrs.Robinson(central_longitude=0) # define target coordinate frame
geo = ccrs.PlateCarree() # define origin coordinate frame

plt.figure(figsize=(12,5))
ax = plt.subplot(1, 1, 1, projection=robin)

#set min/max values for the colorbar
norm = mpl.colors.Normalize(vmin=0, vmax=8)

q = temperature_change.plot(ax=ax, cmap='YlOrRd',norm=norm, transform = geo) # plot a colormap in transformed coordinates

#add coastlines
ax.coastlines()
#Add title with the model name
title = 'mean over 2023-2033' 
plt.title(title);
#save figure
plt.savefig("UKESM1-0-LL Temp Anomaly 1.5C Global Map.png")

# %% [markdown]
# ## Plotting UKESM1-0-LL at time of temperature 2.0°C

# %%
def minpass(mymarks, mypass):
    passed= [x for x in mymarks if x >= mypass]
    min_value = passed[0]
    for x in passed: 
        if x < min_value:
            min_value = x
    return min_value

x = gsat4_roll 
y = 2.0

pass_min = minpass(x, y)
print(pass_min)
# Out:
# <xarray.DataArray 'tas anomaly (relative to 1850-1900)' ()>
# array(2.0042648, dtype=float32)
# Coordinates:
#     year     int64 2038

# %%
minyear=pass_min.year.values - 5
maxyear=pass_min.year.values + 5
min_max = '%s - %s' %(minyear, maxyear)
min_max
# Out:
# '2033 - 2043'

# %%
temperature_change = (
    ssp_hot2['tas'].sel(time=slice('2033','2043')).mean(dim='time') -
    ssp_hot2['tas'].sel(time=slice('1850','1900')).mean(dim='time')
).compute()
temperature_change.attrs.update(ssp_hot2.attrs)
temperature_change = temperature_change.rename(
    r'Temperature anomaly ($^{\circ}$C) from 1850-1900'
)

# %%
#choose projection: robinson projection
robin = ccrs.Robinson(central_longitude=0) # define target coordinate frame
geo = ccrs.PlateCarree() # define origin coordinate frame

plt.figure(figsize=(12,5))
ax = plt.subplot(1, 1, 1, projection=robin)

#set min/max values for the colorbar
norm = mpl.colors.Normalize(vmin=0, vmax=10)

q = temperature_change.plot(ax=ax, cmap='YlOrRd',norm=norm, transform = geo) # plot a colormap in transformed coordinates

#add coastlines
ax.coastlines()
#Add title with the model name
title = '%s surface air temperature anomaly at global mean 2.0$^{\circ}$C (%s)' %(ssp_hot2.attrs['parent_source_id'], min_max)
plt.title(title);
#save figure
plt.savefig("UKESM1-0-LL Temp Anomaly 2.0C Global Map.png")

# %% [markdown]
# ## Plotting UKESM1-0-LL at end-of-century wrt to pre-industrial

# %%
temperature_change = (
    ssp_hot2['tas'].sel(time=slice('2080','2100')).mean(dim='time') -
    ssp_hot2['tas'].sel(time=slice('1850','1900')).mean(dim='time')
).compute()
temperature_change.attrs.update(ssp_hot2.attrs)
temperature_change = temperature_change.rename(
    r'Temperature anomaly ($^{\circ}$C) from 1850-1900'
)

# %%
#choose projection: robinson projection
robin = ccrs.Robinson(central_longitude=0) # define target coordinate frame
geo = ccrs.PlateCarree() # define origin coordinate frame

plt.figure(figsize=(12,5))
ax = plt.subplot(1, 1, 1, projection=robin)

#set min/max values for the colorbar
norm = mpl.colors.Normalize(vmin=0, vmax=10)

q = temperature_change.plot(ax=ax, cmap='YlOrRd',norm=norm, transform = geo) # plot a colormap in transformed coordinates

#add coastlines
ax.coastlines()

#Add title with the model name (parent_source_id is the model name, from the dataset attributes)
title = '%s surface air temperature anomaly at end-of-century' %(ssp_hot2.attrs['parent_source_id'])
plt.title(title);

#save figure
plt.savefig("UKESM1-0-LL Temp Anomaly Endofcentury Global Map.png")

# %% [markdown]
# # Plotting Maps of cold model: MIROC-ES2L

# %%
# Selecting Model out of dictionary
ssp_cold1 = tas_dict[list(tas_dict.keys())[26]]
ssp_cold1.attrs['parent_source_id']
# Out:
# 'MIROC-ES2L'

# %%
# check units
ssp_cold1.tas.attrs['units']
# Out:
# 'K'

# %%
# convert units to Celcius
ssp_cold1.tas.data = ssp_cold1.tas.data - 273.15
ssp_cold1.tas.attrs['units'] = 'Celcius'
ssp_cold1.tas.attrs['units']
# Out:
# 'Celcius'

# %%
# display years in this dataset
print(ssp_cold1.tas.time)
# Out:
# <xarray.DataArray 'time' (time: 3012)>
# array([cftime.DatetimeNoLeap(1850, 1, 16, 12, 0, 0, 0),
#        cftime.DatetimeNoLeap(1850, 2, 15, 0, 0, 0, 0),
#        cftime.DatetimeNoLeap(1850, 3, 16, 12, 0, 0, 0), ...,
#        cftime.DatetimeNoLeap(2100, 10, 16, 12, 0, 0, 0),
#        cftime.DatetimeNoLeap(2100, 11, 16, 0, 0, 0, 0),
#        cftime.DatetimeNoLeap(2100, 12, 16, 12, 0, 0, 0)], dtype=object)
# Coordinates:
#   * time     (time) object 1850-01-16 12:00:00 ... 2100-12-16 12:00:00
# Attributes:
#     bounds:         time_bnds
#     axis:           T
#     long_name:      time
#     standard_name:  time

# %%
tas = ssp_cold1.tas
tas.shape
# Out:
# (3012, 64, 128)

# %%
plt.figure(figsize=(10,5))

gsat27_roll.plot(linewidth=1, color='black', label='%s' %(ssp_cold1.attrs['parent_source_id']))

# set titel and name for axes
plt.title('Model %s (baseline 1850–1900)' %(ssp_cold1.attrs['parent_source_id']), 
         fontsize = 14, fontweight = 'bold')
plt.xlabel('Time (years)')
plt.ylabel(r'Global-mean surface air temperature anomaly ($^{\circ}$C)')
plt.xlim([1850,2100])

# plotting legend
plt.legend()
    
# adding horizontal lines 1.5°C and 2°C
plt.axhline(1.5, color='dimgrey', linestyle='--', linewidth=0.5)
plt.axhline(2.0, color='dimgrey', linestyle='--', linewidth=0.5)

plt.savefig("MIROC-ES2L Time Series Temperature.jpg")

plt.show();

# %% [markdown]
# ## Plotting MIROC-ES2L at time of temperature 1.5°C

# %%
def minpass(mymarks, mypass):
    passed= [x for x in mymarks if x >= mypass]
    min_value = passed[0]
    for x in passed: 
        if x < min_value:
            min_value = x
    return min_value

x = gsat27_roll 
y = 1.5

pass_min = minpass(x, y)
print(pass_min)
# Out:
# <xarray.DataArray 'tas anomaly (relative to 1850-1900)' ()>
# array(1.5022376, dtype=float32)
# Coordinates:
#     year     int64 2042

# %%
minyear=pass_min.year.values - 5
maxyear=pass_min.year.values + 5
min_max = '%s - %s' %(minyear, maxyear)
min_max
# Out:
# '2037 - 2047'

# %%
temperature_change = (
    ssp_cold1['tas'].sel(time=slice('2037','2047')).mean(dim='time') -
    ssp_cold1['tas'].sel(time=slice('1850','1900')).mean(dim='time')
).compute()
temperature_change.attrs.update(ssp_cold1.attrs)
temperature_change = temperature_change.rename(
    r'Temperature anomaly ($^{\circ}$C) from 1850-1900'
)

# %%
#choose projection: robinson projection
robin = ccrs.Robinson(central_longitude=0) # define target coordinate frame
geo = ccrs.PlateCarree() # define origin coordinate frame

plt.figure(figsize=(12,5))
ax = plt.subplot(1, 1, 1, projection=robin)

#set min/max values for the colorbar
norm = mpl.colors.Normalize(vmin=0, vmax=10)

q = temperature_change.plot(ax=ax, cmap='YlOrRd',norm=norm, transform = geo) # plot a colormap in transformed coordinates

#add coastlines
ax.coastlines()
#Add title with the model name
title = '%s surface air temperature anomaly at global mean 1.5$^{\circ}$C (%s)' %(ssp_cold1.attrs['parent_source_id'], min_max)
plt.title(title);
#save figure
plt.savefig("MIROC-ES2L Temp Anomaly 1.5C Global Map.png")

# %% [markdown]
# ## Plotting MIROC-ES2L at time of temperature 2.0°C

# %%
def minpass(mymarks, mypass):
    passed= [x for x in mymarks if x >= mypass]
    min_value = passed[0]
    for x in passed: 
        if x < min_value:
            min_value = x
    return min_value

x = gsat27_roll 
y = 2.0

pass_min = minpass(x, y)
print(pass_min)
# Out:
# <xarray.DataArray 'tas anomaly (relative to 1850-1900)' ()>
# array(2.0465817, dtype=float32)
# Coordinates:
#     year     int64 2071

# %%
minyear=pass_min.year.values - 5
maxyear=pass_min.year.values + 5
min_max = '%s - %s' %(minyear, maxyear)
min_max
# Out:
# '2066 - 2076'

# %%
temperature_change = (
    ssp_cold1['tas'].sel(time=slice('2066','2076')).mean(dim='time') -
    ssp_cold1['tas'].sel(time=slice('1850','1900')).mean(dim='time')
).compute()
temperature_change.attrs.update(ssp_cold1.attrs)
temperature_change = temperature_change.rename(
    r'Temperature anomaly ($^{\circ}$C) from 1850-1900'
)

# %%
#choose projection: robinson projection
robin = ccrs.Robinson(central_longitude=0) # define target coordinate frame
geo = ccrs.PlateCarree() # define origin coordinate frame

plt.figure(figsize=(12,5))
ax = plt.subplot(1, 1, 1, projection=robin)

#set min/max values for the colorbar
norm = mpl.colors.Normalize(vmin=0, vmax=10)

q = temperature_change.plot(ax=ax, cmap='YlOrRd',norm=norm, transform = geo) # plot a colormap in transformed coordinates

#add coastlines
ax.coastlines()
#Add title with the model name
title = '%s surface air temperature anomaly at global mean 2.0$^{\circ}$C (%s)' %(ssp_cold1.attrs['parent_source_id'], min_max)
plt.title(title);
#save figure
plt.savefig("MIROC-ES2-L Temp Anomaly 2.0C Global Map.png")

# %% [markdown]
# ## Plotting MIROC-ES2L at end-of-century wrt to pre-industrial

# %%
temperature_change = (
    ssp_cold1['tas'].sel(time=slice('2080','2100')).mean(dim='time') -
    ssp_cold1['tas'].sel(time=slice('1850','1900')).mean(dim='time')
).compute()
temperature_change.attrs.update(ssp_cold1.attrs)
temperature_change = temperature_change.rename(
    r'Temperature anomaly ($^{\circ}$C) from 1850-1900'
)

# %%
#choose projection: robinson projection
robin = ccrs.Robinson(central_longitude=0) # define target coordinate frame
geo = ccrs.PlateCarree() # define origin coordinate frame

plt.figure(figsize=(12,5))
ax = plt.subplot(1, 1, 1, projection=robin)

#set min/max values for the colorbar
norm = mpl.colors.Normalize(vmin=0, vmax=10)

q = temperature_change.plot(ax=ax, cmap='YlOrRd',norm=norm, transform = geo) # plot a colormap in transformed coordinates

#add coastlines
ax.coastlines()

#Add title with the model name (parent_source_id is the model name, from the dataset attributes)
title = '%s surface air temperature anomaly at end-of-century' %(ssp_cold1.attrs['parent_source_id'])
plt.title(title);

#save figure
plt.savefig("MIROC-ES2L Temp Anomaly Endofcentury Global Map.png")

# %% [markdown]
# # Plotting Maps of cold model: INM-CM4-8 (1.83 ECS)

# %%
# Selecting CanESM5 out of dictionary
ssp_cold2 = tas_dict[list(tas_dict.keys())[31]]
ssp_cold2.attrs['parent_source_id']
# Out:
# 'INM-CM4-8'

# %%
# check units
ssp_cold2.tas.attrs['units']
# Out:
# 'K'

# %%
# convert units to Celcius
ssp_cold2.tas.data = ssp_cold2.tas.data - 273.15
ssp_cold2.tas.attrs['units'] = 'Celcius'
ssp_cold2.tas.attrs['units']
# Out:
# 'Celcius'

# %%
tas = ssp_cold2.tas
tas.shape
# Out:
# (3012, 120, 180)

# %%
plt.figure(figsize=(10,5))

gsat32_roll.plot(linewidth=1, color='black', label='%s' %(ssp_cold2.attrs['parent_source_id']))

# set titel and name for axes
plt.title('Model %s (baseline 1850–1900)' %(ssp_cold2.attrs['parent_source_id']), 
         fontsize = 14, fontweight = 'bold')
plt.xlabel('Time (years)')
plt.ylabel(r'Global-mean surface air temperature anomaly ($^{\circ}$C)')
plt.xlim([1850,2100])

# plotting legend
plt.legend()
    
# adding horizontal lines 1.5°C and 2°C
plt.axhline(1.5, color='dimgrey', linestyle='--', linewidth=0.5)
plt.axhline(2.0, color='dimgrey', linestyle='--', linewidth=0.5)

plt.savefig("INM-CM4-8 Time Series Temperature.png")

plt.show();

# %% [markdown]
# ## Plotting INM-CM4-8 at time of temperature 1.5°C

# %%
def minpass(mymarks, mypass):
    passed= [x for x in mymarks if x >= mypass]
    min_value = passed[0]
    for x in passed: 
        if x < min_value:
            min_value = x
    return min_value

x = gsat32_roll 
y = 1.5

pass_min = minpass(x, y)
print(pass_min)
# Out:
# <xarray.DataArray 'tas anomaly (relative to 1850-1900)' ()>
# array(1.5156503, dtype=float32)
# Coordinates:
#     year     int64 2042

# %%
minyear=pass_min.year.values - 5
maxyear=pass_min.year.values + 5
min_max = '%s - %s' %(minyear, maxyear)
min_max
# Out:
# '2037 - 2047'

# %%
temperature_change = (
    ssp_cold2['tas'].sel(time=slice('2037','2047')).mean(dim='time') -
    ssp_cold2['tas'].sel(time=slice('1850','1900')).mean(dim='time')
).compute()
temperature_change.attrs.update(ssp_cold2.attrs)
temperature_change = temperature_change.rename(
    r'Temperature anomaly ($^{\circ}$C) from 1850-1900'
)

# %%
#choose projection: robinson projection
robin = ccrs.Robinson(central_longitude=0) # define target coordinate frame
geo = ccrs.PlateCarree() # define origin coordinate frame

plt.figure(figsize=(12,5))
ax = plt.subplot(1, 1, 1, projection=robin)

#set min/max values for the colorbar
norm = mpl.colors.Normalize(vmin=0, vmax=10)

q = temperature_change.plot(ax=ax, cmap='YlOrRd',norm=norm, transform = geo) # plot a colormap in transformed coordinates

#add coastlines
ax.coastlines()
#Add title with the model name
title = '%s surface air temperature anomaly at global mean 1.5$^{\circ}$C (%s)' %(ssp_cold2.attrs['parent_source_id'], min_max)
plt.title(title);
#save figure
plt.savefig("INM-CM4-8 Temp Anomaly 1.5C Global Map.png")

# %% [markdown]
# ## Plotting INM-CM4-8 at time of temperature 2.0°C

# %%
def minpass(mymarks, mypass):
    passed= [x for x in mymarks if x >= mypass]
    min_value = passed[0]
    for x in passed: 
        if x < min_value:
            min_value = x
    return min_value

x = gsat32_roll 
y = 2.0

pass_min = minpass(x, y)
print(pass_min)
# Out:
# <xarray.DataArray 'tas anomaly (relative to 1850-1900)' ()>
# array(2.0005064, dtype=float32)
# Coordinates:
#     year     int64 2064

# %%
minyear=pass_min.year.values - 5
maxyear=pass_min.year.values + 5
min_max = '%s - %s' %(minyear, maxyear)
min_max
# Out:
# '2059 - 2069'

# %%
temperature_change = (
    ssp_cold2['tas'].sel(time=slice('2059','2069')).mean(dim='time') -
    ssp_cold2['tas'].sel(time=slice('1850','1900')).mean(dim='time')
).compute()
temperature_change.attrs.update(ssp_cold2.attrs)
temperature_change = temperature_change.rename(
    r'Temperature anomaly ($^{\circ}$C) from 1850-1900'
)

# %%
#choose projection: robinson projection
robin = ccrs.Robinson(central_longitude=0) # define target coordinate frame
geo = ccrs.PlateCarree() # define origin coordinate frame

plt.figure(figsize=(12,5))
ax = plt.subplot(1, 1, 1, projection=robin)

#set min/max values for the colorbar
norm = mpl.colors.Normalize(vmin=0, vmax=10)

q = temperature_change.plot(ax=ax, cmap='YlOrRd',norm=norm, transform = geo) # plot a colormap in transformed coordinates

#add coastlines
ax.coastlines()
#Add title with the model name
title = '%s surface air temperature anomaly at global mean 2.0$^{\circ}$C (%s)' %(ssp_cold2.attrs['parent_source_id'], min_max)
plt.title(title);
#save figure
plt.savefig("INM-CM4-8 Temp Anomaly 2.0C Global Map.png")

# %% [markdown]
# ## Plotting INM-CM4-8 at end-of-century wrt to pre-industrial

# %%
ssp_cold2.attrs['parent_source_id']
# Out:
# 'INM-CM4-8'

# %%
temperature_change = (
    ssp_cold2['tas'].sel(time=slice('2080','2100')).mean(dim='time') -
    ssp_cold2['tas'].sel(time=slice('1850','1900')).mean(dim='time')
).compute()
temperature_change.attrs.update(ssp_cold2.attrs)
temperature_change = temperature_change.rename(
    r'Temperature anomaly ($^{\circ}$C) from 1850-1900'
)

# %%
#choose projection: robinson projection
robin = ccrs.Robinson(central_longitude=0) # define target coordinate frame
geo = ccrs.PlateCarree() # define origin coordinate frame

plt.figure(figsize=(12,5))
ax = plt.subplot(1, 1, 1, projection=robin)

#set min/max values for the colorbar
norm = mpl.colors.Normalize(vmin=0, vmax=10)

q = temperature_change.plot(ax=ax, cmap='YlOrRd',norm=norm, transform = geo) # plot a colormap in transformed coordinates

#add coastlines
ax.coastlines()

#Add title with the model name (parent_source_id is the model name, from the dataset attributes)
title = '%s surface air temperature anomaly at end-of-century' %(ssp_cold2.attrs['parent_source_id'])
plt.title(title);

#save figure
plt.savefig("INM-CM4-8 Temp Anomaly Endofcentury Global Map.png")
